# %%
import pandas as pd
import matplotlib as plt
from sklearn.datasets import make_blobs
import sklearn as skl
import tensorflow as tf
# Out:
# 2023-01-23 15:08:19.176556: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Generate a dummy dataset
X, y = make_blobs(n_samples= 1000, centers = 2, n_features = 2, random_state = 78)

# Create DF with dummy data
df = pd.DataFrame(X, columns=['Feature 1', 'Feature 2'])
df['Target'] = y

# Plot the dummy data
df.plot.scatter(x='Feature 1', y = 'Feature 2', c = 'Target', colormap = 'winter')
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 78)

# %%
# Create scaler instance
X_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the Keras Sequential model
nn_model = tf.keras.models.Sequential()
# Out:
# 2023-01-23 15:19:53.093237: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Add first Dense layer, including input layer
nn_model.add(tf.keras.layers.Dense(units = 1, activation = 'relu', input_dim = 2))

# %%
# Add the output layer that uses a probability activation function
nn_model.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# %%
# Check the structure of the Sequential model
nn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 1)                 3
#
#  dense_1 (Dense)             (None, 1)                 2
#
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the Sequential model together and customize metrics
nn_model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %%
# Fit the model to the training data
fit_model = nn_model.fit(X_train_scaled, y_train, epochs = 100)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 0.6112 - accuracy: 0.9760
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 1.0000
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5824 - accuracy: 1.0000
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5675 - accuracy: 1.0000
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5527 - accuracy: 1.0000
# Epoch 6/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.5377 - accuracy: 1.0000
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5227 - accuracy: 1.0000
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5077 - accuracy: 1.0000
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4927 - accuracy: 1.0000
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4780 - accuracy: 1.0000
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4636 - accuracy: 1.0000
# Epoch 12/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4494 - accuracy: 1.0000
# Epoch 13/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4356 - accuracy: 1.0000
# Epoch 14/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4222 - accuracy: 1.0000
# Epoch 15/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4092 - accuracy: 1.0000
# Epoch 16/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3966 - accuracy: 1.0000
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3846 - accuracy: 1.0000
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3730 - accuracy: 1.0000
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3618 - accuracy: 1.0000
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3511 - accuracy: 1.0000
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3408 - accuracy: 1.0000
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3309 - accuracy: 1.0000
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3215 - accuracy: 1.0000
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3124 - accuracy: 1.0000
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3037 - accuracy: 1.0000
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2954 - accuracy: 1.0000
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2874 - accuracy: 1.0000
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2797 - accuracy: 1.0000
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2723 - accuracy: 1.0000
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2652 - accuracy: 1.0000
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2584 - accuracy: 1.0000
# Epoch 32/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2519 - accuracy: 1.0000
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2456 - accuracy: 1.0000
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2396 - accuracy: 1.0000
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2338 - accuracy: 1.0000
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2281 - accuracy: 1.0000
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2227 - accuracy: 1.0000
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2175 - accuracy: 1.0000
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2124 - accuracy: 1.0000
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2076 - accuracy: 1.0000
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2029 - accuracy: 1.0000
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1984 - accuracy: 1.0000
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1940 - accuracy: 1.0000
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1898 - accuracy: 1.0000
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1856 - accuracy: 1.0000
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1817 - accuracy: 1.0000
# Epoch 47/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1778 - accuracy: 1.0000
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1741 - accuracy: 1.0000
# Epoch 49/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1705 - accuracy: 1.0000
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1670 - accuracy: 1.0000
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1636 - accuracy: 1.0000
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1603 - accuracy: 1.0000
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1571 - accuracy: 1.0000
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1540 - accuracy: 1.0000
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1509 - accuracy: 1.0000
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1480 - accuracy: 1.0000
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 1.0000
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1424 - accuracy: 1.0000
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1397 - accuracy: 1.0000
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1371 - accuracy: 1.0000
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1345 - accuracy: 1.0000
# Epoch 62/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 1.0000
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1296 - accuracy: 1.0000
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1272 - accuracy: 1.0000
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1249 - accuracy: 1.0000
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1226 - accuracy: 1.0000
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1204 - accuracy: 1.0000
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1183 - accuracy: 1.0000
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1162 - accuracy: 1.0000
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 1.0000
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1122 - accuracy: 1.0000
# Epoch 72/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.1102 - accuracy: 1.0000
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1084 - accuracy: 1.0000
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1065 - accuracy: 1.0000
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1047 - accuracy: 1.0000
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 1.0000
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.1012 - accuracy: 1.0000
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0995 - accuracy: 1.0000
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0978 - accuracy: 1.0000
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0962 - accuracy: 1.0000
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0946 - accuracy: 1.0000
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 1.0000
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0916 - accuracy: 1.0000
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 1.0000
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0887 - accuracy: 1.0000
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0873 - accuracy: 1.0000
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0859 - accuracy: 1.0000
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0846 - accuracy: 1.0000
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 1.0000
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0806 - accuracy: 1.0000
# Epoch 92/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0794 - accuracy: 1.0000
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0782 - accuracy: 1.0000
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0770 - accuracy: 1.0000
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0758 - accuracy: 1.0000
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0747 - accuracy: 1.0000
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0725 - accuracy: 1.0000
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0714 - accuracy: 1.0000
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.0703 - accuracy: 1.0000

# %%
# Create a df containing training history
history_df = pd.DataFrame(fit_model.history, index = range(1, len(fit_model.history['loss'])+1))

# Plot the loss
history_df.plot(y = 'loss')
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
history_df.plot(y = 'accuracy')
# Out:
# <AxesSubplot: >

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model.evaluate(X_test_scaled, y_test, verbose = 2)
print(f'Loss: {model_loss}, Accuracy: {model_accuracy}')
# Out:
# 8/8 - 0s - loss: 0.0715 - accuracy: 1.0000 - 254ms/epoch - 32ms/step
# Loss: 0.07151279598474503, Accuracy: 1.0

# %%
# Predict the classification of a new set of data
new_X, new_y = make_blobs(n_samples = 10, centers = 2, n_features = 2, random_state = 78)
new_X_scaled = X_scaler.transform(new_X)
(nn_model.predict(new_X_scaled) > 0.5).astype('int32')
# Alt version? Confusing curriculum
# nn_model.predict_classes(new_X_scaled)
# Out:
# 1/1 [==============================] - 0s 37ms/step
# array([[0],
#        [1],
#        [0],
#        [1],
#        [0],
#        [0],
#        [1],
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
from sklearn.datasets import make_moons

# Create dummy nonlinear data
X_moons, y_moons = make_moons(n_samples = 1000, noise = 0.08, random_state = 78)

# Transform y_moons to a vertical vector
y_moons = y_moons.reshape(-1, 1)

# Create a DF to plot the nonlinear dummy data
df_moons = pd.DataFrame(X_moons, columns = ['Feature 1', 'Feature 2'])
df_moons['Target'] = y_moons

# Plot the nonlinear dummy data
df_moons.plot.scatter(x = 'Feature 1', y = 'Feature 2', c = 'Target', colormap = 'winter')
# Out:
# <AxesSubplot: xlabel='Feature 1', ylabel='Feature 2'>

# %%
# Create training and testing split 
X_moon_train, X_moon_test, y_moon_train, y_moon_test = train_test_split(X_moons, y_moons, random_state = 78)

# %%
# Create the scaler instance
X_moon_scaler = skl.preprocessing.StandardScaler()

# Fit the scaler
X_moon_scaler.fit(X_moon_train)

# Scale the data
X_moon_train_scaled = X_moon_scaler.transform(X_moon_train)
X_moon_test_scaled = X_moon_scaler.transform(X_moon_test)

# %%
# Train the model with nonlinear data
model_moon = nn_model.fit(X_moon_train_scaled, y_moon_train, epochs = 100, shuffle = True)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 2ms/step - loss: 1.0099 - accuracy: 0.5000
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.8895 - accuracy: 0.5333
# Epoch 3/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.8066 - accuracy: 0.5533
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7477 - accuracy: 0.5733
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.7008 - accuracy: 0.5893
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6629 - accuracy: 0.6000
# Epoch 7/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6304 - accuracy: 0.6213
# Epoch 8/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.6030 - accuracy: 0.6373
# Epoch 9/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5779 - accuracy: 0.6453
# Epoch 10/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5564 - accuracy: 0.6547
# Epoch 11/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.5370 - accuracy: 0.6653
# Epoch 12/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5195 - accuracy: 0.6773
# Epoch 13/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.5037 - accuracy: 0.6893
# Epoch 14/100
# 24/24 [==============================] - 0s 4ms/step - loss: 0.4890 - accuracy: 0.7013
# Epoch 15/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4756 - accuracy: 0.7067
# Epoch 16/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.4631 - accuracy: 0.7187
# Epoch 17/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4513 - accuracy: 0.7267
# Epoch 18/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4405 - accuracy: 0.7347
# Epoch 19/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.7400
# Epoch 20/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4206 - accuracy: 0.7587
# Epoch 21/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4115 - accuracy: 0.7653
# Epoch 22/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4030 - accuracy: 0.7760
# Epoch 23/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3949 - accuracy: 0.7800
# Epoch 24/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3870 - accuracy: 0.7840
# Epoch 25/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3798 - accuracy: 0.7907
# Epoch 26/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3727 - accuracy: 0.7933
# Epoch 27/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3664 - accuracy: 0.8000
# Epoch 28/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3601 - accuracy: 0.8107
# Epoch 29/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3545 - accuracy: 0.8133
# Epoch 30/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3491 - accuracy: 0.8187
# Epoch 31/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3442 - accuracy: 0.8200
# Epoch 32/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.3394 - accuracy: 0.8253
# Epoch 33/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3352 - accuracy: 0.8267
# Epoch 34/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3313 - accuracy: 0.8280
# Epoch 35/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.8307
# Epoch 36/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3241 - accuracy: 0.8320
# Epoch 37/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3206 - accuracy: 0.8320
# Epoch 38/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3176 - accuracy: 0.8360
# Epoch 39/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3146 - accuracy: 0.8387
# Epoch 40/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3117 - accuracy: 0.8400
# Epoch 41/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3092 - accuracy: 0.8453
# Epoch 42/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3066 - accuracy: 0.8480
# Epoch 43/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3043 - accuracy: 0.8520
# Epoch 44/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.3020 - accuracy: 0.8533
# Epoch 45/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2999 - accuracy: 0.8573
# Epoch 46/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2978 - accuracy: 0.8613
# Epoch 47/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2958 - accuracy: 0.8640
# Epoch 48/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2941 - accuracy: 0.8667
# Epoch 49/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2924 - accuracy: 0.8667
# Epoch 50/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2907 - accuracy: 0.8667
# Epoch 51/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2892 - accuracy: 0.8667
# Epoch 52/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2877 - accuracy: 0.8667
# Epoch 53/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2863 - accuracy: 0.8680
# Epoch 54/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2850 - accuracy: 0.8707
# Epoch 55/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2837 - accuracy: 0.8720
# Epoch 56/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2824 - accuracy: 0.8733
# Epoch 57/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2813 - accuracy: 0.8747
# Epoch 58/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2802 - accuracy: 0.8760
# Epoch 59/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2791 - accuracy: 0.8773
# Epoch 60/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2781 - accuracy: 0.8773
# Epoch 61/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2771 - accuracy: 0.8787
# Epoch 62/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.8800
# Epoch 63/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2753 - accuracy: 0.8800
# Epoch 64/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2744 - accuracy: 0.8813
# Epoch 65/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2736 - accuracy: 0.8840
# Epoch 66/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2728 - accuracy: 0.8840
# Epoch 67/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2720 - accuracy: 0.8840
# Epoch 68/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2713 - accuracy: 0.8840
# Epoch 69/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2706 - accuracy: 0.8840
# Epoch 70/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2699 - accuracy: 0.8840
# Epoch 71/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2693 - accuracy: 0.8840
# Epoch 72/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2687 - accuracy: 0.8853
# Epoch 73/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2681 - accuracy: 0.8853
# Epoch 74/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2675 - accuracy: 0.8853
# Epoch 75/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2670 - accuracy: 0.8853
# Epoch 76/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2665 - accuracy: 0.8840
# Epoch 77/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.8853
# Epoch 78/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2654 - accuracy: 0.8867
# Epoch 79/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2650 - accuracy: 0.8853
# Epoch 80/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2645 - accuracy: 0.8853
# Epoch 81/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2641 - accuracy: 0.8853
# Epoch 82/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2636 - accuracy: 0.8867
# Epoch 83/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2633 - accuracy: 0.8867
# Epoch 84/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2628 - accuracy: 0.8880
# Epoch 85/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2625 - accuracy: 0.8867
# Epoch 86/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2620 - accuracy: 0.8867
# Epoch 87/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2617 - accuracy: 0.8880
# Epoch 88/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2613 - accuracy: 0.8867
# Epoch 89/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2612 - accuracy: 0.8893
# Epoch 90/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2607 - accuracy: 0.8893
# Epoch 91/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2605 - accuracy: 0.8880
# Epoch 92/100
# 24/24 [==============================] - 0s 3ms/step - loss: 0.2601 - accuracy: 0.8893
# Epoch 93/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2598 - accuracy: 0.8893
# Epoch 94/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2595 - accuracy: 0.8893
# Epoch 95/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2593 - accuracy: 0.8893
# Epoch 96/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.8893
# Epoch 97/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2587 - accuracy: 0.8893
# Epoch 98/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2585 - accuracy: 0.8893
# Epoch 99/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2583 - accuracy: 0.8893
# Epoch 100/100
# 24/24 [==============================] - 0s 2ms/step - loss: 0.2581 - accuracy: 0.8907

# %%
# Create DF containing training history
history_df = pd.DataFrame(model_moon.history, index = range(1, len(model_moon.history['loss'])+1))

# Plot the loss
history_df.plot(y = 'loss')
# Out:
# <AxesSubplot: >

# %%
# Plot the accuracy
history_df.plot(y = 'accuracy')
# Out:
# <AxesSubplot: >
